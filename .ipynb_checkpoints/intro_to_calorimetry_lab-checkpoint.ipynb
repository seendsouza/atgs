# %%
    print("Sean D'Souza\n\nTask 1")
    import pandas as pd
    import numpy as np
    df1 = pd.read_csv("./test1.csv")
    df2 = df1.iloc[68:]
    slope_equation = np.polyfit(df2["Latest: Time (s)"],df2["Latest: Temperature (°C)"], 1)
    slope_thing = np.poly1d(slope_equation)
    df1['Trendline'] = slope_thing(df1["Latest: Time (s)"])
# Out:
# Sean D'Souza
#
# Task 1

# %%
ax=df1.plot(x="Latest: Time (s)",y="Latest: Temperature (°C)")
ax.set_ylabel("Latest: Temperature (°C)")
ax.set_xlim(left=0)
bx=df1.plot(ax=ax,x="Latest: Time (s)",y="Trendline",title="Temperature vs. Time After the Addition of Hot Water to Cold Water")
